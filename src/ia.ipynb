# %%
import pandas as pd
from pycaret.regression import *


data = pd.read_csv("C:/Users/edwin/OneDrive - Universidad de Boyacá/Escritorio/IA_proyecto/DatosC.csv", sep=';')
setup(data, target='precio',  train_size=0.8)
# Out:
# <style type="text/css">
# #T_0bcbf_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_0bcbf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0bcbf_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_0bcbf_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0bcbf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0bcbf_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_0bcbf_row0_col1" class="data row0 col1" >6101</td>
#     </tr>
#     <tr>
#       <th id="T_0bcbf_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0bcbf_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_0bcbf_row1_col1" class="data row1 col1" >precio</td>
#     </tr>
#     <tr>
#       <th id="T_0bcbf_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0bcbf_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_0bcbf_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_0bcbf_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0bcbf_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_0bcbf_row3_col1" class="data row3 col1" >(32000, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_0bcbf_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0bcbf_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_0bcbf_row4_col1" class="data row4 col1" >(32000, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_0bcbf_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0bcbf_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_0bcbf_row5_col1" class="data row5 col1" >(25600, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_0bcbf_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0bcbf_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_0bcbf_row6_col1" class="data row6 col1" >(6400, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_0bcbf_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0bcbf_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_0bcbf_row7_col1" class="data row7 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_0bcbf_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0bcbf_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_0bcbf_row8_col1" class="data row8 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_0bcbf_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0bcbf_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_0bcbf_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_0bcbf_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_0bcbf_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_0bcbf_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_0bcbf_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_0bcbf_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_0bcbf_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_0bcbf_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_0bcbf_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_0bcbf_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_0bcbf_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_0bcbf_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_0bcbf_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_0bcbf_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_0bcbf_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_0bcbf_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_0bcbf_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_0bcbf_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_0bcbf_row15_col1" class="data row15 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_0bcbf_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_0bcbf_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_0bcbf_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_0bcbf_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_0bcbf_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_0bcbf_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_0bcbf_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_0bcbf_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_0bcbf_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_0bcbf_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_0bcbf_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_0bcbf_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_0bcbf_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_0bcbf_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_0bcbf_row20_col1" class="data row20 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_0bcbf_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_0bcbf_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_0bcbf_row21_col1" class="data row21 col1" >f043</td>
#     </tr>
#   </tbody>
# </table>

# %%
from pycaret.regression import compare_models, pull

# best_model = compare_models()
# results = pull()
# print(results)

compare_models()
# Out:
# XGBRegressor(base_score=None, booster='gbtree', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device='cpu', early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=None,
#              n_jobs=-1, num_parallel_tree=None, ...)

# %% [markdown]
# Guardar el modelo

# %%
from pycaret.regression import save_model

best_model = compare_models()
# Out:
# <style type="text/css">
# #T_52a0d th {
#   text-align: left;
# }
# #T_52a0d_row0_col0, #T_52a0d_row0_col1, #T_52a0d_row0_col2, #T_52a0d_row0_col3, #T_52a0d_row0_col5, #T_52a0d_row0_col6, #T_52a0d_row1_col0, #T_52a0d_row1_col5, #T_52a0d_row1_col6, #T_52a0d_row2_col0, #T_52a0d_row2_col1, #T_52a0d_row2_col2, #T_52a0d_row2_col3, #T_52a0d_row2_col4, #T_52a0d_row3_col0, #T_52a0d_row3_col1, #T_52a0d_row3_col2, #T_52a0d_row3_col3, #T_52a0d_row3_col4, #T_52a0d_row3_col5, #T_52a0d_row3_col6, #T_52a0d_row4_col0, #T_52a0d_row4_col1, #T_52a0d_row4_col2, #T_52a0d_row4_col3, #T_52a0d_row4_col4, #T_52a0d_row4_col5, #T_52a0d_row4_col6, #T_52a0d_row5_col0, #T_52a0d_row5_col1, #T_52a0d_row5_col2, #T_52a0d_row5_col3, #T_52a0d_row5_col4, #T_52a0d_row5_col5, #T_52a0d_row5_col6, #T_52a0d_row6_col0, #T_52a0d_row6_col1, #T_52a0d_row6_col2, #T_52a0d_row6_col3, #T_52a0d_row6_col4, #T_52a0d_row6_col5, #T_52a0d_row6_col6, #T_52a0d_row7_col0, #T_52a0d_row7_col1, #T_52a0d_row7_col2, #T_52a0d_row7_col3, #T_52a0d_row7_col4, #T_52a0d_row7_col5, #T_52a0d_row7_col6, #T_52a0d_row8_col0, #T_52a0d_row8_col1, #T_52a0d_row8_col2, #T_52a0d_row8_col3, #T_52a0d_row8_col4, #T_52a0d_row8_col5, #T_52a0d_row8_col6, #T_52a0d_row9_col0, #T_52a0d_row9_col1, #T_52a0d_row9_col2, #T_52a0d_row9_col3, #T_52a0d_row9_col4, #T_52a0d_row9_col5, #T_52a0d_row9_col6, #T_52a0d_row10_col0, #T_52a0d_row10_col1, #T_52a0d_row10_col2, #T_52a0d_row10_col3, #T_52a0d_row10_col4, #T_52a0d_row10_col5, #T_52a0d_row10_col6, #T_52a0d_row11_col0, #T_52a0d_row11_col1, #T_52a0d_row11_col2, #T_52a0d_row11_col3, #T_52a0d_row11_col4, #T_52a0d_row11_col5, #T_52a0d_row11_col6, #T_52a0d_row12_col0, #T_52a0d_row12_col1, #T_52a0d_row12_col2, #T_52a0d_row12_col3, #T_52a0d_row12_col4, #T_52a0d_row12_col5, #T_52a0d_row12_col6, #T_52a0d_row13_col0, #T_52a0d_row13_col1, #T_52a0d_row13_col2, #T_52a0d_row13_col3, #T_52a0d_row13_col4, #T_52a0d_row13_col5, #T_52a0d_row13_col6, #T_52a0d_row14_col0, #T_52a0d_row14_col1, #T_52a0d_row14_col2, #T_52a0d_row14_col3, #T_52a0d_row14_col4, #T_52a0d_row14_col5, #T_52a0d_row14_col6, #T_52a0d_row15_col0, #T_52a0d_row15_col1, #T_52a0d_row15_col2, #T_52a0d_row15_col3, #T_52a0d_row15_col4, #T_52a0d_row15_col5, #T_52a0d_row15_col6, #T_52a0d_row16_col0, #T_52a0d_row16_col1, #T_52a0d_row16_col2, #T_52a0d_row16_col3, #T_52a0d_row16_col4, #T_52a0d_row16_col5, #T_52a0d_row16_col6, #T_52a0d_row17_col0, #T_52a0d_row17_col1, #T_52a0d_row17_col2, #T_52a0d_row17_col3, #T_52a0d_row17_col4, #T_52a0d_row17_col5, #T_52a0d_row17_col6, #T_52a0d_row18_col0, #T_52a0d_row18_col1, #T_52a0d_row18_col2, #T_52a0d_row18_col3, #T_52a0d_row18_col4, #T_52a0d_row18_col5, #T_52a0d_row18_col6 {
#   text-align: left;
# }
# #T_52a0d_row0_col4, #T_52a0d_row1_col1, #T_52a0d_row1_col2, #T_52a0d_row1_col3, #T_52a0d_row1_col4, #T_52a0d_row2_col5, #T_52a0d_row2_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_52a0d_row0_col7, #T_52a0d_row1_col7, #T_52a0d_row2_col7, #T_52a0d_row3_col7, #T_52a0d_row4_col7, #T_52a0d_row5_col7, #T_52a0d_row6_col7, #T_52a0d_row7_col7, #T_52a0d_row8_col7, #T_52a0d_row9_col7, #T_52a0d_row10_col7, #T_52a0d_row11_col7, #T_52a0d_row12_col7, #T_52a0d_row13_col7, #T_52a0d_row14_col7, #T_52a0d_row15_col7, #T_52a0d_row16_col7, #T_52a0d_row18_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_52a0d_row17_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_52a0d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_52a0d_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_52a0d_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_52a0d_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_52a0d_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_52a0d_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_52a0d_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_52a0d_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_52a0d_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_52a0d_level0_row0" class="row_heading level0 row0" >xgboost</th>
#       <td id="T_52a0d_row0_col0" class="data row0 col0" >Extreme Gradient Boosting</td>
#       <td id="T_52a0d_row0_col1" class="data row0 col1" >1874285.6938</td>
#       <td id="T_52a0d_row0_col2" class="data row0 col2" >9813685265339.4297</td>
#       <td id="T_52a0d_row0_col3" class="data row0 col3" >3132456.9354</td>
#       <td id="T_52a0d_row0_col4" class="data row0 col4" >0.9994</td>
#       <td id="T_52a0d_row0_col5" class="data row0 col5" >0.0990</td>
#       <td id="T_52a0d_row0_col6" class="data row0 col6" >0.0524</td>
#       <td id="T_52a0d_row0_col7" class="data row0 col7" >0.0710</td>
#     </tr>
#     <tr>
#       <th id="T_52a0d_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_52a0d_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_52a0d_row1_col1" class="data row1 col1" >1762413.2407</td>
#       <td id="T_52a0d_row1_col2" class="data row1 col2" >9062337902232.3223</td>
#       <td id="T_52a0d_row1_col3" class="data row1 col3" >3010160.2142</td>
#       <td id="T_52a0d_row1_col4" class="data row1 col4" >0.9994</td>
#       <td id="T_52a0d_row1_col5" class="data row1 col5" >0.0507</td>
#       <td id="T_52a0d_row1_col6" class="data row1 col6" >0.0332</td>
#       <td id="T_52a0d_row1_col7" class="data row1 col7" >0.5150</td>
#     </tr>
#     <tr>
#       <th id="T_52a0d_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_52a0d_row2_col0" class="data row2 col0" >Random Forest Regressor</td>
#       <td id="T_52a0d_row2_col1" class="data row2 col1" >1831639.7396</td>
#       <td id="T_52a0d_row2_col2" class="data row2 col2" >12134496230963.2852</td>
#       <td id="T_52a0d_row2_col3" class="data row2 col3" >3483052.1486</td>
#       <td id="T_52a0d_row2_col4" class="data row2 col4" >0.9992</td>
#       <td id="T_52a0d_row2_col5" class="data row2 col5" >0.0440</td>
#       <td id="T_52a0d_row2_col6" class="data row2 col6" >0.0298</td>
#       <td id="T_52a0d_row2_col7" class="data row2 col7" >0.6260</td>
#     </tr>
#     <tr>
#       <th id="T_52a0d_level0_row3" class="row_heading level0 row3" >gbr</th>
#       <td id="T_52a0d_row3_col0" class="data row3 col0" >Gradient Boosting Regressor</td>
#       <td id="T_52a0d_row3_col1" class="data row3 col1" >2242997.8990</td>
#       <td id="T_52a0d_row3_col2" class="data row3 col2" >12602375843445.6250</td>
#       <td id="T_52a0d_row3_col3" class="data row3 col3" >3549645.0498</td>
#       <td id="T_52a0d_row3_col4" class="data row3 col4" >0.9992</td>
#       <td id="T_52a0d_row3_col5" class="data row3 col5" >0.3407</td>
#       <td id="T_52a0d_row3_col6" class="data row3 col6" >0.1033</td>
#       <td id="T_52a0d_row3_col7" class="data row3 col7" >0.3670</td>
#     </tr>
#     <tr>
#       <th id="T_52a0d_level0_row4" class="row_heading level0 row4" >et</th>
#       <td id="T_52a0d_row4_col0" class="data row4 col0" >Extra Trees Regressor</td>
#       <td id="T_52a0d_row4_col1" class="data row4 col1" >1764203.3087</td>
#       <td id="T_52a0d_row4_col2" class="data row4 col2" >13390312309375.0039</td>
#       <td id="T_52a0d_row4_col3" class="data row4 col3" >3658926.9846</td>
#       <td id="T_52a0d_row4_col4" class="data row4 col4" >0.9992</td>
#       <td id="T_52a0d_row4_col5" class="data row4 col5" >0.0474</td>
#       <td id="T_52a0d_row4_col6" class="data row4 col6" >0.0308</td>
#       <td id="T_52a0d_row4_col7" class="data row4 col7" >0.5780</td>
#     </tr>
#     <tr>
#       <th id="T_52a0d_level0_row5" class="row_heading level0 row5" >dt</th>
#       <td id="T_52a0d_row5_col0" class="data row5 col0" >Decision Tree Regressor</td>
#       <td id="T_52a0d_row5_col1" class="data row5 col1" >1920966.5951</td>
#       <td id="T_52a0d_row5_col2" class="data row5 col2" >18904779596702.4766</td>
#       <td id="T_52a0d_row5_col3" class="data row5 col3" >4347076.1280</td

# %%
#Guardar el modelo
save_model(best_model, 'modeloB')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['niveles', 'area_construida',
#                                               'num_habitaciones', 'num_banos',
#                                               'estrato'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=['tipo_vivienda', 'tipo_contrato',
#                                               'estado', 'parqueadero',
#                                               'sector'],
#                                      transformer=SimpleImputer(strategy='most...
#                                feature_types=None, feature_weights=None,
#                                gamma=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None, learning_rate=None,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=None, max_leaves=None,
#                                min_child_weight=None, missing=nan,
#                                monotone_constraints=None, multi_strategy=None,
#                                n_estimators=None, n_jobs=-1,
#                                num_parallel_tree=None, ...))]),
#  'modeloB.pkl')

# %%
print(data.columns.tolist())
# Out:
# ['tipo_vivienda', 'niveles', 'tipo_contrato', 'area_construida', 'estado', 'num_habitaciones', 'num_banos', 'parqueadero', 'sector', 'estrato', 'precio']

# %%
print(data['precio'].head())
print(data['precio'].dtype)
print(data['precio'].isnull().sum())
# Out:
# 0    4980000
# 1    2060000
# 2    2910000
# 3    8200000
# 4    3250000
# Name: precio, dtype: int64
# int64
# 0

# %%
import pandas as pd
from pycaret.regression import *


data = pd.read_csv("C:/Users/edwin/OneDrive - Universidad de Boyacá/Escritorio/IA_proyecto/Datos.csv", sep=';')
setup(data, target='precio',  train_size=0.8)
# Out:
# <style type="text/css">
# #T_7a695_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_7a695">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7a695_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_7a695_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7a695_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7a695_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_7a695_row0_col1" class="data row0 col1" >1425</td>
#     </tr>
#     <tr>
#       <th id="T_7a695_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7a695_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_7a695_row1_col1" class="data row1 col1" >precio</td>
#     </tr>
#     <tr>
#       <th id="T_7a695_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7a695_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_7a695_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_7a695_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7a695_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_7a695_row3_col1" class="data row3 col1" >(5000, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_7a695_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7a695_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_7a695_row4_col1" class="data row4 col1" >(5000, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_7a695_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7a695_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_7a695_row5_col1" class="data row5 col1" >(4000, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_7a695_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7a695_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_7a695_row6_col1" class="data row6 col1" >(1000, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_7a695_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7a695_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_7a695_row7_col1" class="data row7 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_7a695_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7a695_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_7a695_row8_col1" class="data row8 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_7a695_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7a695_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_7a695_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_7a695_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_7a695_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_7a695_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_7a695_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_7a695_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_7a695_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_7a695_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_7a695_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_7a695_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_7a695_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_7a695_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_7a695_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_7a695_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_7a695_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_7a695_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_7a695_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_7a695_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_7a695_row15_col1" class="data row15 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_7a695_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_7a695_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_7a695_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_7a695_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_7a695_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_7a695_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_7a695_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_7a695_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_7a695_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7a695_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_7a695_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_7a695_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7a695_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_7a695_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_7a695_row20_col1" class="data row20 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_7a695_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_7a695_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_7a695_row21_col1" class="data row21 col1" >ddb0</td>
#     </tr>
#   </tbody>
# </table>

# %%
from pycaret.regression import compare_models, pull

# best_model = compare_models()
# results = pull()
# print(results)

compare_models()
# Out:
# GradientBoostingRegressor(random_state=1425)

# %% [markdown]
# Guardar el modelo

# %%
from pycaret.regression import save_model

best_model = compare_models()
save_model(best_model, 'modelo_gbr')
# Out:
# <style type="text/css">
# #T_0a834 th {
#   text-align: left;
# }
# #T_0a834_row0_col0, #T_0a834_row1_col0, #T_0a834_row1_col1, #T_0a834_row1_col2, #T_0a834_row1_col3, #T_0a834_row1_col4, #T_0a834_row1_col5, #T_0a834_row1_col6, #T_0a834_row2_col0, #T_0a834_row2_col1, #T_0a834_row2_col2, #T_0a834_row2_col3, #T_0a834_row2_col4, #T_0a834_row2_col5, #T_0a834_row2_col6, #T_0a834_row3_col0, #T_0a834_row3_col1, #T_0a834_row3_col2, #T_0a834_row3_col3, #T_0a834_row3_col4, #T_0a834_row3_col5, #T_0a834_row3_col6, #T_0a834_row4_col0, #T_0a834_row4_col1, #T_0a834_row4_col2, #T_0a834_row4_col3, #T_0a834_row4_col4, #T_0a834_row4_col5, #T_0a834_row4_col6, #T_0a834_row5_col0, #T_0a834_row5_col1, #T_0a834_row5_col2, #T_0a834_row5_col3, #T_0a834_row5_col4, #T_0a834_row5_col5, #T_0a834_row5_col6, #T_0a834_row6_col0, #T_0a834_row6_col1, #T_0a834_row6_col2, #T_0a834_row6_col3, #T_0a834_row6_col4, #T_0a834_row6_col5, #T_0a834_row6_col6, #T_0a834_row7_col0, #T_0a834_row7_col1, #T_0a834_row7_col2, #T_0a834_row7_col3, #T_0a834_row7_col4, #T_0a834_row7_col5, #T_0a834_row7_col6, #T_0a834_row8_col0, #T_0a834_row8_col1, #T_0a834_row8_col2, #T_0a834_row8_col3, #T_0a834_row8_col4, #T_0a834_row8_col5, #T_0a834_row8_col6, #T_0a834_row9_col0, #T_0a834_row9_col1, #T_0a834_row9_col2, #T_0a834_row9_col3, #T_0a834_row9_col4, #T_0a834_row9_col5, #T_0a834_row9_col6, #T_0a834_row10_col0, #T_0a834_row10_col1, #T_0a834_row10_col2, #T_0a834_row10_col3, #T_0a834_row10_col4, #T_0a834_row10_col5, #T_0a834_row10_col6, #T_0a834_row11_col0, #T_0a834_row11_col1, #T_0a834_row11_col2, #T_0a834_row11_col3, #T_0a834_row11_col4, #T_0a834_row11_col5, #T_0a834_row11_col6, #T_0a834_row12_col0, #T_0a834_row12_col1, #T_0a834_row12_col2, #T_0a834_row12_col3, #T_0a834_row12_col4, #T_0a834_row12_col5, #T_0a834_row12_col6, #T_0a834_row13_col0, #T_0a834_row13_col1, #T_0a834_row13_col2, #T_0a834_row13_col3, #T_0a834_row13_col4, #T_0a834_row13_col5, #T_0a834_row13_col6, #T_0a834_row14_col0, #T_0a834_row14_col1, #T_0a834_row14_col2, #T_0a834_row14_col3, #T_0a834_row14_col4, #T_0a834_row14_col5, #T_0a834_row14_col6, #T_0a834_row15_col0, #T_0a834_row15_col1, #T_0a834_row15_col2, #T_0a834_row15_col3, #T_0a834_row15_col4, #T_0a834_row15_col5, #T_0a834_row15_col6, #T_0a834_row16_col0, #T_0a834_row16_col1, #T_0a834_row16_col2, #T_0a834_row16_col3, #T_0a834_row16_col4, #T_0a834_row16_col5, #T_0a834_row16_col6, #T_0a834_row17_col0, #T_0a834_row17_col1, #T_0a834_row17_col2, #T_0a834_row17_col3, #T_0a834_row17_col4, #T_0a834_row17_col5, #T_0a834_row17_col6, #T_0a834_row18_col0, #T_0a834_row18_col1, #T_0a834_row18_col2, #T_0a834_row18_col3, #T_0a834_row18_col4, #T_0a834_row18_col5, #T_0a834_row18_col6 {
#   text-align: left;
# }
# #T_0a834_row0_col1, #T_0a834_row0_col2, #T_0a834_row0_col3, #T_0a834_row0_col4, #T_0a834_row0_col5, #T_0a834_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_0a834_row0_col7, #T_0a834_row1_col7, #T_0a834_row2_col7, #T_0a834_row3_col7, #T_0a834_row4_col7, #T_0a834_row5_col7, #T_0a834_row6_col7, #T_0a834_row7_col7, #T_0a834_row8_col7, #T_0a834_row9_col7, #T_0a834_row10_col7, #T_0a834_row11_col7, #T_0a834_row12_col7, #T_0a834_row13_col7, #T_0a834_row14_col7, #T_0a834_row15_col7, #T_0a834_row16_col7, #T_0a834_row18_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_0a834_row17_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_0a834">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0a834_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_0a834_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_0a834_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_0a834_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_0a834_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_0a834_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_0a834_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_0a834_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0a834_level0_row0" class="row_heading level0 row0" >gbr</th>
#       <td id="T_0a834_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_0a834_row0_col1" class="data row0 col1" >3140668.0867</td>
#       <td id="T_0a834_row0_col2" class="data row0 col2" >16115053805484.6055</td>
#       <td id="T_0a834_row0_col3" class="data row0 col3" >4012900.6514</td>
#       <td id="T_0a834_row0_col4" class="data row0 col4" >0.9906</td>
#       <td id="T_0a834_row0_col5" class="data row0 col5" >0.0212</td>
#       <td id="T_0a834_row0_col6" class="data row0 col6" >0.0163</td>
#       <td id="T_0a834_row0_col7" class="data row0 col7" >0.5200</td>
#     </tr>
#     <tr>
#       <th id="T_0a834_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_0a834_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_0a834_row1_col1" class="data row1 col1" >3210356.7694</td>
#       <td id="T_0a834_row1_col2" class="data row1 col2" >17192857881676.6230</td>
#       <td id="T_0a834_row1_col3" class="data row1 col3" >4144845.2314</td>
#       <td id="T_0a834_row1_col4" class="data row1 col4" >0.9900</td>
#       <td id="T_0a834_row1_col5" class="data row1 col5" >0.0220</td>
#       <td id="T_0a834_row1_col6" class="data row1 col6" >0.0166</td>
#       <td id="T_0a834_row1_col7" class="data row1 col7" >0.2290</td>
#     </tr>
#     <tr>
#       <th id="T_0a834_level0_row2" class="row_heading level0 row2" >lasso</th>
#       <td id="T_0a834_row2_col0" class="data row2 col0" >Lasso Regression</td>
#       <td id="T_0a834_row2_col1" class="data row2 col1" >3519849.6473</td>
#       <td id="T_0a834_row2_col2" class="data row2 col2" >18717440889860.8320</td>
#       <td id="T_0a834_row2_col3" class="data row2 col3" >4324499.6663</td>
#       <td id="T_0a834_row2_col4" class="data row2 col4" >0.9891</td>
#       <td id="T_0a834_row2_col5" class="data row2 col5" >0.0229</td>
#       <td id="T_0a834_row2_col6" class="data row2 col6" >0.0182</td>
#       <td id="T_0a834_row2_col7" class="data row2 col7" >0.2980</td>
#     </tr>
#     <tr>
#       <th id="T_0a834_level0_row3" class="row_heading level0 row3" >ridge</th>
#       <td id="T_0a834_row3_col0" class="data row3 col0" >Ridge Regression</td>
#       <td id="T_0a834_row3_col1" class="data row3 col1" >3519466.5969</td>
#       <td id="T_0a834_row3_col2" class="data row3 col2" >18719247042327.9141</td>
#       <td id="T_0a834_row3_col3" class="data row3 col3" >4324692.0055</td>
#       <td id="T_0a834_row3_col4" class="data row3 col4" >0.9891</td>
#       <td id="T_0a834_row3_col5" class="data row3 col5" >0.0229</td>
#       <td id="T_0a834_row3_col6" class="data row3 col6" >0.0182</td>
#       <td id="T_0a834_row3_col7" class="data row3 col7" >0.3190</td>
#     </tr>
#     <tr>
#       <th id="T_0a834_level0_row4" class="row_heading level0 row4" >lar</th>
#       <td id="T_0a834_row4_col0" class="data row4 col0" >Least Angle Regression</td>
#       <td id="T_0a834_row4_col1" class="data row4 col1" >3519849.7274</td>
#       <td id="T_0a834_row4_col2" class="data row4 col2" >18717441396842.6797</td>
#       <td id="T_0a834_row4_col3" class="data row4 col3" >4324499.7246</td>
#       <td id="T_0a834_row4_col4" class="data row4 col4" >0.9891</td>
#       <td id="T_0a834_row4_col5" class="data row4 col5" >0.0229</td>
#       <td id="T_0a834_row4_col6" class="data row4 col6" >0.0182</td>
#       <td id="T_0a834_row4_col7" class="data row4 col7" >0.0360</td>
#     </tr>
#     <tr>
#       <th id="T_0a834_level0_row5" class="row_heading level0 row5" >llar</th>
#       <td id="T_0a834_row5_col0" class="data row5 col0" >Lasso Least Angle Regression</td>
#       <td id="T_0a834_row5_col1" class="data row5 col1" >3519849.6397</td>
#       <td id="T_0a834_row5_col2" class="data row5 col2" >18717440933818.7891</td>
#       <td id="T_0a834_row5_col3" class="data row5 col3" >4324499.6717</td>
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['niveles', 'num_habitaciones',
#                                               'num_banos', 'area_construida',
#                                               'estrato'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=['tipo_vivienda', 'tipo_contrato',
#                                               'estado', 'parqueadero',
#                                               'sector'],
#                                      transformer=SimpleImputer(strategy='most...
#                                                                          {'col': 'parqueadero',
#                                                                           'data_type': dtype('O'),
#                                                                           'mapping': No     0
#  Si     1
#  NaN   -1
#  dtype: int64}]))),
#                  ('onehot_encoding',
#                   TransformerWrapper(include=['tipo_vivienda', 'tipo_contrato',
#                                               'sector'],
#                                      transformer=OneHotEncoder(cols=['tipo_vivienda',
#                                                                      'tipo_contrato',
#                                                                      'sector'],
#                                                                handle_missing='return_nan',
#                                                                use_cat_names=True))),
#                  ('trained_model',
#                   GradientBoostingRegressor(random_state=1425))]),
#  'modelo_gbr.pkl')

# %%
print(data.columns.tolist())
# Out:
# ['tipo_vivienda', 'niveles', 'tipo_contrato', 'estado', 'num_habitaciones', 'num_banos', 'area_construida', 'parqueadero', 'sector', 'estrato', 'precio']

# %%
print(data['precio'].head())
print(data['precio'].dtype)
print(data['precio'].isnull().sum())
# Out:
# 0    260000000
# 1    260000000
# 2    210000000
# 3    200000000
# 4    240000000
# Name: precio, dtype: int64
# int64
# 0

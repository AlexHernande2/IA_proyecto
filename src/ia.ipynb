# %%
import pandas as pd
from pycaret.regression import *


data = pd.read_csv("C:/Users/edwin/OneDrive - Universidad de Boyacá/Escritorio/IA_proyecto/DatosFinales.csv", sep=';')
setup(data, target='precio',  train_size=0.8)
# Out:
# <style type="text/css">
# #T_b2d48_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b2d48">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b2d48_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_b2d48_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b2d48_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b2d48_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_b2d48_row0_col1" class="data row0 col1" >2424</td>
#     </tr>
#     <tr>
#       <th id="T_b2d48_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b2d48_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_b2d48_row1_col1" class="data row1 col1" >precio</td>
#     </tr>
#     <tr>
#       <th id="T_b2d48_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
from pycaret.regression import compare_models, pull

# best_model = compare_models()
# results = pull()
# print(results)

compare_models()
# Out:
# <style type="text/css">
# #T_ebd4c th {
#   text-align: left;
# }
# ...

# %% [markdown]
# Guardar el modelo

# %%
from pycaret.regression import save_model

best_model = compare_models()
# Out:
# <style type="text/css">
# #T_4c277 th {
#   text-align: left;
# }
# ...

# %%
#Guardar el modelo
save_model(best_model, 'modeloB')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['niveles', 'area_construida',
#                                               'num_habitaciones', 'num_banos',
#                                               'estrato'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=['tipo_vivienda', 'tipo_contrato',
#                                               'estado', 'parqueadero',
#                                               'sector'],
#                                      transformer=SimpleImputer(strategy='most...
#                                                                           'data_type': dtype('O'),
#                                                                           'mapping': Casi nuevo    0
#  Nuevo         1
# ...

# %%
print(data.columns.tolist())
# Out:
# ['tipo_vivienda', 'niveles', 'tipo_contrato', 'area_construida', 'estado', 'num_habitaciones', 'num_banos', 'parqueadero', 'sector', 'estrato', 'precio']

# %%
print(data['precio'].head())
print(data['precio'].dtype)
print(data['precio'].isnull().sum())
# Out:
# 0    4980000
# 1    2060000
# 2    2910000
# 3    8200000
# 4    3250000
# Name: precio, dtype: int64
# int64
# 0
